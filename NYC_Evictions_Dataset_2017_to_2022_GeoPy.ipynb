# %% [markdown]
# **Evictions Dataset Description**
#
# This dataset lists pending, scheduled, and executed evictions within the five boroughs,
# for the year 2017 - early 2022. The data fields may be sorted by Court Index Number,
# Docket Number, Eviction Address, Apartment Number, Executed Date, Marshal First
# Name, Marshal Last Name, Residential or Commercial (property type), Borough, Zip
# Code and Scheduled Status (Pending/Scheduled).

# %% [markdown]
# 1. Import pandas

# %%
import pandas as pd

# %% [markdown]
# 2. Read CSV into DataFrame

# %%
evictions_df = pd.read_csv('Evictions.csv')
evictions_df
# Out:
#       Court Index Number  Docket Number          Eviction Address  \
# 0               50365/19          352435     319 WEST 94TH STREET
# 1             B068159/16          379048         2332 CRESTON AVE
# 2               59891/16          320691   2670 BAINBRIDGE AVENUE
# 3               75708/18          115775          18-24 25TH ROAD
# 4              900940/18           86395  3005 EASTCHESTER  RO AD
# ...                  ...             ...                      ...
# 67723         R 50452/17           68450     182 ARLINGTON AVENUE
# 67724          N66489/17           81749   600 WEST 136TH STREE T
# 67725         60675/17-1          208636         115 LINCOLN ROAD
# 67726          B42335/17           83318  1131-1133 OGDEN AVEN UE
# 67727           20290/16           59510             5 FLEET WALK
#
#       Eviction Apartment Number Executed Date Marshal First Name  \
# 0                          C103    03/25/2019             Thomas
# 1                            41    04/25/2017            Richard
# 2                            2F    02/21/2017               John
# 3                             1    04/23/2019             Maxine
# 4                    STOREFRONT    11/08/2018             Justin
# ...                         ...           ...                ...
# 67723                       NaN    03/29/2017             Steven
# 67724                        6F    09/27/2017             Ileana
# 67725                        3N    01/09/2020            Richard
# 67726                       12A    12/13/2017             Ileana
# 67727                       08E    08/02/2017             Justin
#
#       Marshal Last Name Residential/Commercial        BOROUGH  \
# 0                   Bia            Residential      MANHATTAN
# 1                 McCoy            Residential          BRONX
# 2            Villanueva            Residential          BRONX
# 3              Chevlowe            Residential         QUEENS
# 4              Grossman             Commercial          BRONX
# ...                 ...                    ...            ...
# 67723            Powell            Residential  STATEN ISLAND
# 67724            Rivera            Residential      MANHATTAN
# 67725           Capuano            Residential       BROOKLYN
# 67726            Rivera            Residential          BRONX
# 67727          Grossman            Residential       BROOKLYN
#
#        Eviction Postcode         Ejectment Eviction/Legal Possession  \
# 0                  10025  Not an Ejectment                Possession
# 1                  10468  Not an Ejectment                Possession
# 2                  10458  Not an Ejectment                Possession
# 3                  11102  Not an Ejectment                Possession
# 4                  10469  Not an Ejectment                Possession
# ...                  ...               ...                       ...
# 67723              10303  Not an Ejectment                Possession
# 67724              10031  Not an Ejectment                Possession
# 67725              11225  Not an Ejectment                Possession
# 67726              10452  Not an Ejectment                Possession
# 67727              11201  Not an Ejectment                Possession
#
#         Latitude  Longitude  Community Board  Council District  Census Tract  \
# 0      40.794205 -73.974734              7.0               6.0         183.0
# 1      40.858643 -73.900402              5.0              14.0       23703.0
# 2      40.865470 -73.891472              7.0              15.0       40502.0
# 3      40.774861 -73.926140              1.0              22.0          91.0
# 4      40.869607 -73.842766             12.0              12.0         358.0
# ...          ...        ...              ...               ...           ...
# 67723  40.635485 -74.167531              1.0              49.0         323.0
# 67724  40.820935 -73.954996              9.0               7.0       22301.0
# 67725  40.661077 -73.958799              9.0              40.0       79801.0
# 67726  40.836286 -73.927496              4.0              16.0         199.0
# 67727  40.695529 -73.981230              2.0              35.0          15.0
#
#              BIN           BBL  \
# 0      1034178.0  1.012530e+09
# 1      2013777.0  2.031640e+09
# 2      2016620.0  2.032870e+09
# 3      4019956.0  4.008870e+09
# 4      2061802.0  2.047620e+09
# ...          ...           ...
# 67723  5028488.0  5.012670e+09
# 67724  1059959.0  1.020020e+09
# 67725  3379187.0  3.013270e+09
# 67726  2088158.0  2.025260e+09
# 67727  3257046.0  3.020500e+09
#
#                                                      NTA
# 0                                        Upper West Side
# 1                                          Fordham South
# 2                             Bedford Park-Fordham North
# 3                                            Old Astoria
# 4                        Eastchester-Edenwald-Baychester
# ...                                                  ...
# 67723  Mariner's Harbor-Arlington-Port Ivory-Granitev...
# 67724                                     Manhattanville
# 67725                  Prospect Lefferts Gardens-Wingate
# 67726                                         Highbridge
# 67727   DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill
#
# [67728 rows x 20 columns]

# %% [markdown]
# 3. Explore the data and its structure

# %%
# .shape shows the number of rows and columns
evictions_df.shape
# Out:
# (67728, 20)

# %%
# .dtypes shows the data types
evictions_df.dtypes
# Out:
# Court Index Number            object
# Docket Number                  int64
# Eviction Address              object
# Eviction Apartment Number     object
# Executed Date                 object
# Marshal First Name            object
# Marshal Last Name             object
# Residential/Commercial        object
# BOROUGH                       object
# Eviction Postcode              int64
# Ejectment                     object
# Eviction/Legal Possession     object
# Latitude                     float64
# Longitude                    float64
# Community Board              float64
# Council District             float64
# Census Tract                 float64
# BIN                          float64
# BBL                          float64
# NTA                           object
# dtype: object

# %%
# .isnull() detects missing values
# To get the total summation of all missing values in the dataframe,
# chain two .sum() methods together
evictions_df.isnull().sum().sum()
# Out:
# 62997

# %% [markdown]
# The DataFrame contains 62997 missing values. We want to further investigate where these missing values are.

# %%
# .isna() detects missing values in columns
evictions_df.isna().sum()
# Out:
# Court Index Number               0
# Docket Number                    0
# Eviction Address                 0
# Eviction Apartment Number    11209
# Executed Date                    0
# Marshal First Name               0
# Marshal Last Name                0
# Residential/Commercial           0
# BOROUGH                          0
# Eviction Postcode                0
# Ejectment                        0
# Eviction/Legal Possession        0
# Latitude                      6444
# Longitude                     6444
# Community Board               6444
# Council District              6444
# Census Tract                  6444
# BIN                           6562
# BBL                           6562
# NTA                           6444
# dtype: int64

# %% [markdown]
# Missing values:
#
#
# *   11209 missing values in the 'Eviction Apartment Number' column
# *   6444 missing values in the 'Latitude' column
# * 6444 missing values in the 'Longitude' column
# * 6444 missing values in the 'Community Board' column
# * 6444 missing values in the 'Council District' column
# * 6444 missing values in the 'Census Tract' column
# * 6562 missing values in the 'BIN' column
# * 6562 missing values in the 'BBL' column
# * 6444 missing values in the 'NTA' column

# %% [markdown]
# 4. Investigate the missing values and clean the data

# %%
# Missing values in the Eviction Apartment Number column
# Not all Eviction Addresses are apartments
# Hence we will ignore this

# %%
# Missing values in the Latitude and Longitude column
# We have the eviction address, borough, and postcode
# We can perform geocoding in Python using the Geopy Library
# Install the library using Pip
# Documentation: https://geopy.readthedocs.io/en/latest/#geocoders

# !pip install geopy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: geopy in /usr/local/lib/python3.9/dist-packages (2.3.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.9/dist-packages (from geopy) (2.0)

# %%
# Creating a new column in the DataFrame to hold the eviction full address
evictions_df.loc[:, 'full_address'] = evictions_df['Eviction Address'] + "," + evictions_df['BOROUGH'] + ",NY," + evictions_df['Eviction Postcode'].astype(str)
evictions_df.head()
# Out:
#   Court Index Number  Docket Number          Eviction Address  \
# 0           50365/19          352435     319 WEST 94TH STREET
# 1         B068159/16          379048         2332 CRESTON AVE
# 2           59891/16          320691   2670 BAINBRIDGE AVENUE
# 3           75708/18          115775          18-24 25TH ROAD
# 4          900940/18           86395  3005 EASTCHESTER  RO AD
#
#   Eviction Apartment Number Executed Date Marshal First Name  \
# 0                      C103    03/25/2019             Thomas
# 1                        41    04/25/2017            Richard
# 2                        2F    02/21/2017               John
# 3                         1    04/23/2019             Maxine
# 4                STOREFRONT    11/08/2018             Justin
#
#   Marshal Last Name Residential/Commercial    BOROUGH  Eviction Postcode  ...  \
# 0               Bia            Residential  MANHATTAN              10025  ...
# 1             McCoy            Residential      BRONX              10468  ...
# 2        Villanueva            Residential      BRONX              10458  ...
# 3          Chevlowe            Residential     QUEENS              11102  ...
# 4          Grossman             Commercial      BRONX              10469  ...
#
#   Eviction/Legal Possession   Latitude  Longitude  Community Board  \
# 0                Possession  40.794205 -73.974734              7.0
# 1                Possession  40.858643 -73.900402              5.0
# 2                Possession  40.865470 -73.891472              7.0
# 3                Possession  40.774861 -73.926140              1.0
# 4                Possession  40.869607 -73.842766             12.0
#
#    Council District  Census Tract        BIN           BBL  \
# 0               6.0         183.0  1034178.0  1.012530e+09
# 1              14.0       23703.0  2013777.0  2.031640e+09
# 2              15.0       40502.0  2016620.0  2.032870e+09
# 3              22.0          91.0  4019956.0  4.008870e+09
# 4              12.0         358.0  2061802.0  2.047620e+09
#
#                                NTA                             full_address
# 0                  Upper West Side  319 WEST 94TH STREET,MANHATTAN,NY,10025
# 1                    Fordham South          2332 CRESTON AVE,BRONX,NY,10468
# 2       Bedford Park-Fordham North    2670 BAINBRIDGE AVENUE,BRONX,NY,10458
# 3                      Old Astoria          18-24 25TH ROAD,QUEENS,NY,11102
# 4  Eastchester-Edenwald-Baychester   3005 EASTCHESTER  RO AD,BRONX,NY,10469
#
# [5 rows x 21 columns]

# %%
# Use the Nominatim geocoding service
# There are many geocoding services so why this one?
# This one does not require an API key to access

# Note - Limitation of Nominatim Usage - maximum of 1 request per second
# We have a total of 67728 rows - 67728 secs = 18.81 hrs
# We have 6444 values missing in the lat and long columns
# This equivalates to a runtime of 6444 secs = 1.79 hrs

# Approach - we could loop through the DataFrame and only populate the
# geocodes for the missing values and extract the lat and long,
# but this would still take approximately 2 hours

# // the line below populates geocode for all values
# evictions_df['geocodes'] = evictions_df.full_address.apply(geolocator.geocode)

# %% [markdown]
# Python Geopy Nominatim too many requests 403 error
#
# Stackoverflow Solution: https://stackoverflow.com/questions/60083187/python-geopy-nominatim-too-many-requests

# %%
import logging
from time import sleep
from random import randint
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut, GeocoderServiceError

# Generate a random user agent to be used with the geolocator
user_agent = 'user_me_{}'.format(randint(10000,99999))
# Create a geolocator object using the Nominatim geocoder with the user agent
geolocator = Nominatim(user_agent=user_agent)

def reverse_geocode(geolocator, latlon, sleep_sec):
    try:
        # Try to get the location information from the geolocator
        return geolocator.geocode(latlon)
    except GeocoderTimedOut:
        # If there is a timeout error, log the message and retry after waiting for some random time
        logging.info('TIMED OUT: GeocoderTimedOut: Retrying...')
        sleep(randint(1*100,sleep_sec*100)/100)
        return reverse_geocode(geolocator, latlon, sleep_sec)
    except GeocoderServiceError as e:
        # If there is a service error, log the message and return None
        logging.info('CONNECTION REFUSED: GeocoderServiceError encountered.')
        logging.error(e)
        return None
    except Exception as e:
        # If there is any other exception, log the message and return None
        logging.info('ERROR: Terminating due to exception {}'.format(e))
        return None

# %%
# Iterate through each row of the evictions_df DataFrame
for i, row in evictions_df.iterrows():
    # If the Latitude or Longitude values are NaN
    if pd.isna(row['Latitude']) or pd.isna(row['Longitude']):
        # Use the reverse_geocode function to get the location information from the geolocator
        location = reverse_geocode(geolocator, row['full_address'], 1)
        # If location information is obtained successfully
        if location is not None:
            # Set the Latitude value of the corresponding row of the DataFrame
            evictions_df.at[i, 'Latitude'] = location.latitude
            # Set the Longitude value of the corresponding row of the DataFrame
            evictions_df.at[i, 'Longitude'] = location.longitude
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=34-16+88+STREET+++2ND+FLOOR+FRONT+ROOM+LEFT%2CQUEENS%2CNY%2C11372&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=34-16+88+STREET+++2ND+FLOOR+FRONT+ROOM+LEFT%2CQUEENS%2CNY%2C11372&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=34-16+88+STREET+++2ND+FLOOR+FRONT+ROOM+LEFT%2CQUEENS%2CNY%2C11372&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=37-13+THROUGH+09+22N++STREET+N%2FK%2FA+37-09%2CQUEENS%2CNY%2C11101&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=37-13+THROUGH+09+22N++STREET+N%2FK%2FA+37-09%2CQUEENS%2CNY%2C11101&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=1165+BROADWAY+STORE+%234+AND+ROOM+204%2CMANHATTAN%2CNY%2C10001&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=1165+BROADWAY+STORE+%234+AND+ROOM+204%2CMANHATTAN%2CNY%2C10001&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=1165+BROADWAY+STORE+%234+AND+ROOM+204%2CMANHATTAN%2CNY%2C10001&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=89-27+118TH+STREET+%28ROOM+3%29%2CQUEENS%2CNY%2C11418&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=119-05+METROPOLITAN++AVENUE++ON+THE+2ND%2CQUEENS%2CNY%2C11415&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=119-05+METROPOLITAN++AVENUE++ON+THE+2ND%2CQUEENS%2CNY%2C11415&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=119-05+METROPOLITAN++AVENUE++ON+THE+2ND%2CQUEENS%2CNY%2C11415&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=629+LENOX+AVENUE+GROUND+FLOOR+RETAIL+STORE%2CMANHATTAN%2CNY%2C10037&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=43-37+9TH+STREET+++WAREHOUSE%2CQUEENS%2CNY%2C11101&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=43-37+9TH+STREET+++WAREHOUSE%2CQUEENS%2CNY%2C11101&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=43-37+9TH+STREET+++WAREHOUSE%2CQUEENS%2CNY%2C11101&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=3339+BAY+CT.+%28A%2FK%2FA+33-39+BAY+COURT%29%2CQUEENS%2CNY%2C11691&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=3339+BAY+CT.+%28A%2FK%2FA+33-39+BAY+COURT%29%2CQUEENS%2CNY%2C11691&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=3339+BAY+CT.+%28A%2FK%2FA+33-39+BAY+COURT%29%2CQUEENS%2CNY%2C11691&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=238-40+148+DRIVE%2CQUEENS%2CNY%2C11422&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=412+BEDFORD+AVENUE+++APT+3-3RD+FL%2CBROOKLYN%2CNY%2C11249&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=412+BEDFORD+AVENUE+++APT+3-3RD+FL%2CBROOKLYN%2CNY%2C11249&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=412+BEDFORD+AVENUE+++APT+3-3RD+FL%2CBROOKLYN%2CNY%2C11249&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=59+CANAL+STREET++FRONT+ENTRANCE%2CSTATEN+ISLAND%2CNY%2C10304&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=394+MONTGOMERY+ST.+%28GROUND+FLOOR%29%2CBROOKLYN%2CNY%2C11225&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=178-18+146+ROAD%2CQUEENS%2CNY%2C11434&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=178-18+146+ROAD%2CQUEENS%2CNY%2C11434&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=178-18+146+ROAD%2CQUEENS%2CNY%2C11434&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=104+1ST+PLACE+AND+10+6+1ST+PLACE%2CBROOKLYN%2CNY%2C11231&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=104+1ST+PLACE+AND+10+6+1ST+PLACE%2CBROOKLYN%2CNY%2C11231&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=104+1ST+PLACE+AND+10+6+1ST+PLACE%2CBROOKLYN%2CNY%2C11231&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=2218+FULTON+STREET+UNIT%3A+1ST+FLOOR%2CBROOKLYN%2CNY%2C11223&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=2218+FULTON+STREET+UNIT%3A+1ST+FLOOR%2CBROOKLYN%2CNY%2C11223&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=2218+FULTON+STREET+UNIT%3A+1ST+FLOOR%2CBROOKLYN%2CNY%2C11223&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=37-53+83+STREET+ON+THE+5TH+FLOOR%2CQUEENS%2CNY%2C11372&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=37-53+83+STREET+ON+THE+5TH+FLOOR%2CQUEENS%2CNY%2C11372&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=37-53+83+STREET+ON+THE+5TH+FLOOR%2CQUEENS%2CNY%2C11372&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=195+BEACH+96+STREET+SECOND+FLOOR+APT.%2CQUEENS%2CNY%2C11693&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=195+BEACH+96+STREET+SECOND+FLOOR+APT.%2CQUEENS%2CNY%2C11693&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=195+BEACH+96+STREET+SECOND+FLOOR+APT.%2CQUEENS%2CNY%2C11693&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=178-74+WEXFORD+TERRA+CE%2CQUEENS%2CNY%2C11432&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=573+EAST+22ND+STREET+THIRD+ROOM+ON+4TH+FL%2CBROOKLYN%2CNY%2C11226&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=443+BEACH+43+STREET+APT.+NO.+1F+2ND+FL%2CQUEENS%2CNY%2C11691&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=443+BEACH+43+STREET+APT.+NO.+1F+2ND+FL%2CQUEENS%2CNY%2C11691&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=443+BEACH+43+STREET+APT.+NO.+1F+2ND+FL%2CQUEENS%2CNY%2C11691&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=219-27+112+ROAD%2CQUEENS%2CNY%2C11429&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=219-27+112+ROAD%2CQUEENS%2CNY%2C11429&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=219-27+112+ROAD%2CQUEENS%2CNY%2C11429&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=219-27+112+ROAD%2CQUEENS%2CNY%2C11429&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=219-27+112+ROAD%2CQUEENS%2CNY%2C11429&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=219-27+112+ROAD%2CQUEENS%2CNY%2C11429&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=42-16+80+ST.%2C%2CQUEENS%2CNY%2C11373&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=42-16+80+ST.%2C%2CQUEENS%2CNY%2C11373&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=42-16+80+ST.%2C%2CQUEENS%2CNY%2C11373&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=103-28+102ND+ST+++1ST+FLOOR+APT%2CQUEENS%2CNY%2C11417&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=1082+ROGERS+AVE+APT.2+2ND+FL+FRONT%2CBROOKLYN%2CNY%2C11226&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=865+FIRST+AVENUE+-+COMMERCIAL+CONDOMINIUM+UNIT+NO.+1%2CMANHATTAN%2CNY%2C10017&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=109+KENILWORTH+PLACE+2ND+FL.+APT%2CBROOKLYN%2CNY%2C11210&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=2013+AVENUE+T+%283RD+FLOOR%29%2CBROOKLYN%2CNY%2C11229&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=84-20+AUSTIN+STREET+LOT+L-SPACE+%2324+OF+THE+WYOMING+BUILDING%2CQUEENS%2CNY%2C11415&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=84-20+AUSTIN+STREET+LOT+L-SPACE+%2324+OF+THE+WYOMING+BUILDING%2CQUEENS%2CNY%2C11415&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=84-20+AUSTIN+STREET+LOT+L-SPACE+%2324+OF+THE+WYOMING+BUILDING%2CQUEENS%2CNY%2C11415&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=902+MADISON+STREET+APT.+GROUND+FLOOR%2CBROOKLYN%2CNY%2C11221&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=300+YORK+AVENUE++FRONT+ENTRANCE%2CSTATEN+ISLAND%2CNY%2C10301&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=392+CENTRAL+PARK+WES+T%2CMANHATTAN%2CNY%2C10025&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=392+CENTRAL+PARK+WES+T%2CMANHATTAN%2CNY%2C10025&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=392+CENTRAL+PARK+WES+T%2CMANHATTAN%2CNY%2C10025&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=5520+GLENWOOD+ROAD+SUITE+1B-+THE+OFFICE%2CBROOKLYN%2CNY%2C11234&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=5520+GLENWOOD+ROAD+SUITE+1B-+THE+OFFICE%2CBROOKLYN%2CNY%2C11234&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=5520+GLENWOOD+ROAD+SUITE+1B-+THE+OFFICE%2CBROOKLYN%2CNY%2C11234&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=191-08+115+ROAD%2CQUEENS%2CNY%2C11412&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=191-08+115+ROAD%2CQUEENS%2CNY%2C11412&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=191-08+115+ROAD%2CQUEENS%2CNY%2C11412&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=139-81+35TH+AVE+++PARKING+SPACE+%2317%2CQUEENS%2CNY%2C11354&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=7803-13+AVENUE%2CBROOKLYN%2CNY%2C11228&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=148-51+EDGEWOOD+ST+1ST+FLOOR+APT%2CQUEENS%2CNY%2C11422&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=148-51+EDGEWOOD+ST+1ST+FLOOR+APT%2CQUEENS%2CNY%2C11422&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=148-51+EDGEWOOD+ST+1ST+FLOOR+APT%2CQUEENS%2CNY%2C11422&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=67+35TH+ST.%28BLDG%235%29+%28WEST+C-SECTION%29%2CBROOKLYN%2CNY%2C11232&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=67+35TH+ST.%28BLDG%235%29+%28WEST+C-SECTION%29%2CBROOKLYN%2CNY%2C11232&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=67+35TH+ST.%28BLDG%235%29+%28WEST+C-SECTION%29%2CBROOKLYN%2CNY%2C11232&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=41-44%2F46+MAIN+STREET%2CQUEENS%2CNY%2C11355&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=41-44%2F46+MAIN+STREET%2CQUEENS%2CNY%2C11355&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=41-44%2F46+MAIN+STREET%2CQUEENS%2CNY%2C11355&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=14-30+CENTRAL+AVENUE++%281ST+FLOOR%29%2CQUEENS%2CNY%2C11691&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=133-60+41ST+AVENUE+++4TH+FLOOR+APT.%2CQUEENS%2CNY%2C11354&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=641+62ND+STREET+GROUND+FLOOR+STORE+UNIT+G%2CBROOKLYN%2CNY%2C11220&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=353+LINWOOD+STREET+%28APT.2+RM.4%29%2CBROOKLYN%2CNY%2C11208&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=1901+LEXINGTON+AVENUE+4TH+FLOOR+APT.+15%2CMANHATTAN%2CNY%2C10035&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=57+CLINTON+STREET+-+GROUND+FL+SOUTH+STORE%2CMANHATTAN%2CNY%2C10002&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=716+EAST+181+ST++APT.%23APT+1%2FRM+1%2CBRONX%2CNY%2C10457&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=89-16+102+ROAD%2CQUEENS%2CNY%2C11416&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=89-16+102+ROAD%2CQUEENS%2CNY%2C11416&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=524+WEST+134+ST++1+AKA+1F%2CMANHATTAN%2CNY%2C10031&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=524+WEST+134+ST++1+AKA+1F%2CMANHATTAN%2CNY%2C10031&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=524+WEST+134+ST++1+AKA+1F%2CMANHATTAN%2CNY%2C10031&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=105-58+130TH+STREET+FRONT+ENTRANCE%2C+FIRST+FLOOR%2CQUEENS%2CNY%2C11419&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=109-18+LIBERTY+AVENUE+-+2ND+FL+APT%2CQUEENS%2CNY%2C11419&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=109-18+LIBERTY+AVENUE+-+2ND+FL+APT%2CQUEENS%2CNY%2C11419&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=109-18+LIBERTY+AVENUE+-+2ND+FL+APT%2CQUEENS%2CNY%2C11419&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=140-20+33RD+AVENUE+A.K.A.+140-20+33RD+AVENUE%2CQUEENS%2CNY%2C11354&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=140-20+33RD+AVENUE+A.K.A.+140-20+33RD+AVENUE%2CQUEENS%2CNY%2C11354&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=140-20+33RD+AVENUE+A.K.A.+140-20+33RD+AVENUE%2CQUEENS%2CNY%2C11354&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=133-20+AVERY+AVE+9B-+10B+A%2FK%2FA+9B+AND+10B%2CQUEENS%2CNY%2C11355&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=88-32+179TH+STREET+++2ND+FL+APT%2CQUEENS%2CNY%2C11432&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=219+SHERMAN+AVE+IN+T+HE+BLDG+K%2FA+213-%2A%2CMANHATTAN%2CNY%2C10034&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=219+SHERMAN+AVE+IN+T+HE+BLDG+K%2FA+213-%2A%2CMANHATTAN%2CNY%2C10034&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=219+SHERMAN+AVE+IN+T+HE+BLDG+K%2FA+213-%2A%2CMANHATTAN%2CNY%2C10034&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=57-36+XENIA+STREET+APT+3+ON+THE+3RD+FLOOR%2CQUEENS%2CNY%2C11368&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=788+FOX+STREET+STREET+LEVEL+SUPER%27S+UNIT%2CBRONX%2CNY%2C10455&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=1099+FLUSHING+AVENUE++%28A%2FK%2FA+120+THAMES+S%2CBROOKLYN%2CNY%2C11237&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=157-08+115+ROAD%2CQUEENS%2CNY%2C11434&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=157-08+115+ROAD%2CQUEENS%2CNY%2C11434&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=157-08+115+ROAD%2CQUEENS%2CNY%2C11434&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=77+BISHOP+ST.+RIGHT+FRONT+ENTRANCE%2CSTATEN+ISLAND%2CNY%2C10306&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=657-661+LEXINGTON++AVE%2F135+E+55%2CMANHATTAN%2CNY%2C10022&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=657-661+LEXINGTON++AVE%2F135+E+55%2CMANHATTAN%2CNY%2C10022&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=657-661+LEXINGTON++AVE%2F135+E+55%2CMANHATTAN%2CNY%2C10022&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=94-06+34+ROAD%2CQUEENS%2CNY%2C11372&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=94-06+34+ROAD%2CQUEENS%2CNY%2C11372&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=94-06+34+ROAD%2CQUEENS%2CNY%2C11372&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=909+GREEN+AVENUE%2CBROOKLYN%2CNY%2C11221&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=118+MILLER+AVE+APT+2+2ND+FL%2CBROOKLYN%2CNY%2C11207&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=118+MILLER+AVE+APT+2+2ND+FL%2CBROOKLYN%2CNY%2C11207&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=118+MILLER+AVE+APT+2+2ND+FL%2CBROOKLYN%2CNY%2C11207&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=188-30+LINDEN+BLVD++1+ROOM+ON+1ST+FL.ON%2CQUEENS%2CNY%2C11412&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=188-30+LINDEN+BLVD++1+ROOM+ON+1ST+FL.ON%2CQUEENS%2CNY%2C11412&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=188-30+LINDEN+BLVD++1+ROOM+ON+1ST+FL.ON%2CQUEENS%2CNY%2C11412&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=257-05+148+ROAD%2CQUEENS%2CNY%2C11422&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=257-05+148+ROAD%2CQUEENS%2CNY%2C11422&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=257-05+148+ROAD%2CQUEENS%2CNY%2C11422&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=215-08+111+ROAD%2CQUEENS%2CNY%2C11413&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=215-08+111+ROAD%2CQUEENS%2CNY%2C11413&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=215-08+111+ROAD%2CQUEENS%2CNY%2C11413&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=920+HANCOCK+STREET+APT.+D+3RD+FL%2CBROOKLYN%2CNY%2C11233&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=920+HANCOCK+STREET+APT.+D+3RD+FL%2CBROOKLYN%2CNY%2C11233&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=920+HANCOCK+STREET+APT.+D+3RD+FL%2CBROOKLYN%2CNY%2C11233&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=474+CENTRAL+PARK+WES+T%2CMANHATTAN%2CNY%2C10025&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=474+CENTRAL+PARK+WES+T%2CMANHATTAN%2CNY%2C10025&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=474+CENTRAL+PARK+WES+T%2CMANHATTAN%2CNY%2C10025&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# ...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=1570+EAST+N.Y.+AVE%2CBROOKLYN%2CNY%2C11212&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=1570+EAST+N.Y.+AVE%2CBROOKLYN%2CNY%2C11212&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=1570+EAST+N.Y.+AVE%2CBROOKLYN%2CNY%2C11212&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=3339+BAY+CT.+%28A%2FK%2FA+33-39+BAY+COURT%29%2CQUEENS%2CNY%2C11691&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=3339+BAY+CT.+%28A%2FK%2FA+33-39+BAY+COURT%29%2CQUEENS%2CNY%2C11691&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=3339+BAY+CT.+%28A%2FK%2FA+33-39+BAY+COURT%29%2CQUEENS%2CNY%2C11691&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=143-22+FERNDALE+AVE.+%28A+ONE+FAMILY+HOUSE%29%2CQUEENS%2CNY%2C11435&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=143-22+FERNDALE+AVE.+%28A+ONE+FAMILY+HOUSE%29%2CQUEENS%2CNY%2C11435&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=143-22+FERNDALE+AVE.+%28A+ONE+FAMILY+HOUSE%29%2CQUEENS%2CNY%2C11435&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=153-14+NORTHERN+BLVD+UNIT%3A+%25+RETAIL+STORE+%281ST+%26+2ND+FL%29%2CQUEENS%2CNY%2C11354&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=153-14+NORTHERN+BLVD+UNIT%3A+%25+RETAIL+STORE+%281ST+%26+2ND+FL%29%2CQUEENS%2CNY%2C11354&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=153-14+NORTHERN+BLVD+UNIT%3A+%25+RETAIL+STORE+%281ST+%26+2ND+FL%29%2CQUEENS%2CNY%2C11354&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=6224+FORT+HAMILTON+P+KWY+A%2FK%2FA+937+63+STREET%2CBROOKLYN%2CNY%2C11219&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=6224+FORT+HAMILTON+P+KWY+A%2FK%2FA+937+63+STREET%2CBROOKLYN%2CNY%2C11219&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=6224+FORT+HAMILTON+P+KWY+A%2FK%2FA+937+63+STREET%2CBROOKLYN%2CNY%2C11219&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=85-29+60TH+ROAD+APARTMENT+NO.+1%2CQUEENS%2CNY%2C11379&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=237+SUNNYSIDE+AVENUE++APT.+NO.2+2ND+FLOOR%2CBROOKLYN%2CNY%2C11207&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=237+SUNNYSIDE+AVENUE++APT.+NO.2+2ND+FLOOR%2CBROOKLYN%2CNY%2C11207&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=237+SUNNYSIDE+AVENUE++APT.+NO.2+2ND+FLOOR%2CBROOKLYN%2CNY%2C11207&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=867+EAST+21ST++ROOM+ON+THE+3RD+FL%2CBROOKLYN%2CNY%2C11210&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=867+EAST+21ST++ROOM+ON+THE+3RD+FL%2CBROOKLYN%2CNY%2C11210&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=867+EAST+21ST++ROOM+ON+THE+3RD+FL%2CBROOKLYN%2CNY%2C11210&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=238-39+148+DR.+APT+%232+ON+THE+SECOND+FLOOR%2CQUEENS%2CNY%2C11422&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=238-39+148+DR.+APT+%232+ON+THE+SECOND+FLOOR%2CQUEENS%2CNY%2C11422&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=238-39+148+DR.+APT+%232+ON+THE+SECOND+FLOOR%2CQUEENS%2CNY%2C11422&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=420+LEXINGTON+AVENUE++ROOM+1617-20+AND+ST%2CMANHATTAN%2CNY%2C10170&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=420+LEXINGTON+AVENUE++ROOM+1617-20+AND+ST%2CMANHATTAN%2CNY%2C10170&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=420+LEXINGTON+AVENUE++ROOM+1617-20+AND+ST%2CMANHATTAN%2CNY%2C10170&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=314+FIFTH+AVE.++GROUND+LEVEL+STORE%2CMANHATTAN%2CNY%2C10001&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=801+PINE+STREET+-+APT+FLOOR+1%2CBROOKLYN%2CNY%2C11208&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=801+PINE+STREET+-+APT+FLOOR+1%2CBROOKLYN%2CNY%2C11208&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=901+JEFFERSON+AVE+-+APT+1+%281ST+FL%29%2CBROOKLYN%2CNY%2C11213&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=901+JEFFERSON+AVE+-+APT+1+%281ST+FL%29%2CBROOKLYN%2CNY%2C11213&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=901+JEFFERSON+AVE+-+APT+1+%281ST+FL%29%2CBROOKLYN%2CNY%2C11213&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=2681+FULTON+ST+-+APT+2+%282ND+FL%29%2CBROOKLYN%2CNY%2C11207&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=2681+FULTON+ST+-+APT+2+%282ND+FL%29%2CBROOKLYN%2CNY%2C11207&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=2681+FULTON+ST+-+APT+2+%282ND+FL%29%2CBROOKLYN%2CNY%2C11207&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=84-20+AUSTIN+STREET+LOT+L-SPACE+%2326+OF+THE+WYOMING+BUILDING%2CQUEENS%2CNY%2C11415&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=84-20+AUSTIN+STREET+LOT+L-SPACE+%2326+OF+THE+WYOMING+BUILDING%2CQUEENS%2CNY%2C11415&format=json&limit=1
# ERROR:root:HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=84-20+AUSTIN+STREET+LOT+L-SPACE+%2326+OF+THE+WYOMING+BUILDING%2CQUEENS%2CNY%2C11415&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=110+MARTIN+LUTHER+KI+NG+JR.+PLACE%2CBROOKLYN%2CNY%2C11206&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=88+ROBIN+ROAD++WALK+IN%2CSTATEN+ISLAND%2CNY%2C10305&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=88+ROBIN+ROAD++WALK+IN%2CSTATEN+ISLAND%2CNY%2C10305&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=438+LINWOOD+STREET+-+APT+1+%281ST+FLOOR%29%2CBROOKLYN%2CNY%2C11207&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=261+BUFFALO+AVENUE++%28STORE+%233%29%2CBROOKLYN%2CNY%2C11213&format=json&limit=1

# %%
# View the changes in the number of missing values in Latitude and Longitude columns

# .isna() detects missing values in columns
evictions_df.isna().sum()
# Out:
# Court Index Number               0
# Docket Number                    0
# Eviction Address                 0
# Eviction Apartment Number    11209
# Executed Date                    0
# Marshal First Name               0
# Marshal Last Name                0
# Residential/Commercial           0
# BOROUGH                          0
# Eviction Postcode                0
# Ejectment                        0
# Eviction/Legal Possession        0
# Latitude                      6000
# Longitude                     6000
# Community Board               6444
# Council District              6444
# Census Tract                  6444
# BIN                           6562
# BBL                           6562
# NTA                           6444
# full_address                     0
# dtype: int64

# %%
evictions_df.to_csv("evictions_geocode_version.csv", index=False)
